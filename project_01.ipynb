# %%
import pandas as pd

# %%
data=pd.read_csv('indian_liver_patient.csv')

# %%
data.keys()
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
del_ls=data.iloc[:,2:-1].keys()
for i in del_ls:
    del data[i]

# %%
data = data.replace(['Male', 'Female'], [1, 2])

# %%
data.iloc[0,1]
# Out:
# 2

# %%
w=pd.read_excel('weight.xlsx')
#data.iloc[0,0]<=19 && data.iloc[0,1]=1

# %%
new_w=w.iloc[2:4,1:]

# %%
new_w
# Out:
#   성별(1)   2017 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 2    남자  72.25      71.05      74.29      76.75      74.28      70.78
# 3    여자  57.67      58.34      56.49      57.79      58.36      58.19
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 2      68.01      65.29       61.36       61.36
# 3      58.02       56.4       51.67       51.67

# %%
del new_w['2017']
del new_w['성별(1)']

# %%
new_w
#new_w = new_w.replace(['남자', '여자'], [1, 2])
# Out:
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 2      71.05      74.29      76.75      74.28      70.78      68.01
# 3      58.34      56.49      57.79      58.36      58.19      58.02
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 2      65.29       61.36       61.36
# 3       56.4       51.67       51.67

# %%
new_w
# Out:
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 2      71.05      74.29      76.75      74.28      70.78      68.01
# 3      58.34      56.49      57.79      58.36      58.19      58.02
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 2      65.29       61.36       61.36
# 3       56.4       51.67       51.67

# %%
ls=[]
for i in range(0,len(data)):
    if data.iloc[i,1]==1:
        moc=data.iloc[i,0]//10
        ls.append(new_w.iloc[0,(moc-1)])
    elif data.iloc[i,1]==2:                
        moc=data.iloc[i,0]//10
        ls.append(new_w.iloc[1,(moc-1)])

# %%
data['Weight']=ls

# %%
import random
# Out:
#      Age  Gender  Dataset  Weight
# 0     65       2        1   58.02
# 1     62       1        1   68.01
# 2     62       1        1   68.01
# 3     58       1        1   70.78
# 4     72       1        1   65.29
# 5     46       1        1   74.28
# 6     26       2        1   56.49
# 7     29       2        1   56.49
# 8     17       1        2   71.05
# 9     55       1        1   70.78
# 10    57       1        1   70.78
# 11    72       1        1   65.29
# 12    64       1        2   68.01
# 13    74       2        1   56.40
# 14    61       1        1   68.01
# 15    25       1        2   74.29
# 16    38       1        1   76.75
# 17    33       1        2   76.75
# 18    40       2        1   58.36
# 19    40       2        1   58.36
# 20    51       1        1   70.78
# 21    51       1        1   70.78
# 22    62       1        1   68.01
# 23    40       1        1   74.28
# 24    63       1        2   68.01
# 25    34       1        1   76.75
# ...
